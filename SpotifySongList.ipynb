# %%
import numpy as np
import pandas as pd
import spotipy as sp
import pickle
from sklearn import datasets # sklearn comes with some toy datasets to practice
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from matplotlib import pyplot
from sklearn.metrics import silhouette_score
##!conda install -c conda-forge spotipy
import config
import pandas
import spotipy
import json
from spotipy.oauth2 import SpotifyClientCredentials
import pprint

#Initialize SpotiPy with user credentials
sp = spotipy.Spotify(auth_manager=SpotifyClientCredentials(client_id= config.client_id,
                                                           client_secret= config.client_secret))

# %%
from IPython.display import IFrame

def play_song(track_id):
    return IFrame(src="https://open.spotify.com/embed/track/"+track_id,
       width="320",
       height="80",
       frameborder="0",
       allowtransparency="true",
       allow="encrypted-media",
      )

# %%
def get_playlist_tracks(username, playlist_id):
    results = sp.user_playlist_tracks(username,playlist_id,market="DE")
    tracks = results['items']
    while results['next']:
        results = sp.next(results)
        tracks.extend(results['items'])
    return tracks

# %% [markdown]
# #### Today's Top Hits

# %%
todays_top = sp.search(q="37i9dQZF1DXcBWIGoYBM5M",limit=5,market="GB")
todays_top

selected_playlist_todays_top = get_playlist_tracks('spotify','37i9dQZF1DXcBWIGoYBM5M')
selected_playlist_todays_top

id_songs_todays_top = []
for i in selected_playlist_todays_top:
    id_songs_todays_top.append(i['track']['id'])
id_songs_todays_top

audio_list_todays_top =[]
for i in id_songs_todays_top:
    audio_list_todays_top.append(sp.audio_features(i)[0])
audio_list_todays_top

audio_list_todays_top = pd.DataFrame(audio_list_todays_top)
audio_list_todays_top
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.552   0.702    9    -5.707     1       0.1570       0.11700
# 1          0.511   0.532    5    -5.745     1       0.0560       0.16900
# 2          0.855   0.678    1    -6.276     1       0.1890       0.05690
# 3          0.671   0.845   11    -4.930     0       0.0480       0.02070
# 4          0.652   0.800    9    -4.019     0       0.0614       0.14300
# 5          0.644   0.728    8    -5.750     1       0.0351       0.05430
# 6          0.707   0.681    0    -4.325     1       0.0668       0.06320
# 7          0.631   0.535    0    -7.836     1       0.0842       0.46400
# 8          0.801   0.806   11    -5.206     1       0.0381       0.38200
# 9          0.520   0.731    6    -5.338     0       0.0557       0.34200
# 10         0.783   0.592   11    -8.332     0       0.0331       0.43500
# 11         0.770   0.580    0    -8.393     1       0.2470       0.51900
# ...

# %% [markdown]
# #### Global Top 50

# %%
global_top = sp.search(q="37i9dQZEVXbMDoHDwVN2tF",limit=5,market="GB")
global_top

selected_playlist_global_top = get_playlist_tracks('spotify','37i9dQZEVXbMDoHDwVN2tF')
selected_playlist_global_top

id_songs_global_top = []
for i in selected_playlist_global_top:
    id_songs_global_top.append(i['track']['id'])
id_songs_global_top

audio_list_global_top =[]
for i in id_songs_global_top:
    audio_list_global_top.append(sp.audio_features(i)[0])
audio_list_global_top

audio_list_global_top = pd.DataFrame(audio_list_global_top)
audio_list_global_top
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.511   0.532    5    -5.745     1       0.0560       0.16900
# 1          0.552   0.702    9    -5.707     1       0.1570       0.11700
# 2          0.668   0.758    5    -5.176     0       0.0332       0.48300
# 3          0.652   0.800    9    -4.019     0       0.0614       0.14300
# 4          0.708   0.737    1    -4.045     1       0.0436       0.07390
# 5          0.707   0.681    0    -4.325     1       0.0668       0.06320
# 6          0.812   0.479    2    -5.678     0       0.3330       0.21300
# 7          0.569   0.724    6    -4.076     0       0.0474       0.22800
# 8          0.508   0.430    2    -9.475     0       0.0335       0.83000
# 9          0.520   0.731    6    -5.338     0       0.0557       0.34200
# 10         0.644   0.728    8    -5.750     1       0.0351       0.05430
# 11         0.916   0.583    1    -8.067     1       0.2410       0.18600
# ...

# %% [markdown]
# #### RapCaviar

# %%
rapcaviar = sp.search(q="37i9dQZF1DX0XUsuxWHRQd",limit=5,market="GB")
rapcaviar

selected_playlist_rapcaviar = get_playlist_tracks('spotify','37i9dQZF1DX0XUsuxWHRQd')
selected_playlist_rapcaviar

id_songs_rapcaviar = []
for i in selected_playlist_rapcaviar:
    id_songs_rapcaviar.append(i['track']['id'])
id_songs_rapcaviar

audio_list_rapcaviar =[]
for i in id_songs_rapcaviar:
    audio_list_rapcaviar.append(sp.audio_features(i)[0])
audio_list_rapcaviar

audio_list_rapcaviar = pd.DataFrame(audio_list_rapcaviar)
audio_list_rapcaviar
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.640   0.609    1    -7.714     0       0.3040      0.492000
# 1          0.808   0.789    7    -5.880     0       0.2360      0.051700
# 2          0.847   0.622    1    -6.747     0       0.0903      0.119000
# 3          0.496   0.638    6    -6.539     0       0.2710      0.271000
# 4          0.678   0.483    1    -7.956     1       0.4220      0.003610
# 5          0.777   0.604    9    -4.452     0       0.0397      0.000713
# 6          0.730   0.729   10    -3.939     0       0.2030      0.060200
# 7          0.773   0.607   10    -6.768     0       0.3820      0.035400
# 8          0.817   0.440   10    -8.482     0       0.0734      0.060300
# 9          0.829   0.436    3    -8.205     1       0.3270      0.150000
# 10         0.896   0.581   11    -6.293     1       0.2420      0.033400
# 11         0.783   0.609    6    -7.222     0       0.1590      0.057600
# ...

# %% [markdown]
# #### Viva Latino

# %%
vivalatino = sp.search(q="37i9dQZF1DX10zKzsJ2jva",limit=5,market="GB")
vivalatino

selected_playlist_vivalatino = get_playlist_tracks('spotify','37i9dQZF1DX10zKzsJ2jva')
selected_playlist_vivalatino

id_songs_vivalatino = []
for i in selected_playlist_vivalatino:
    id_songs_vivalatino.append(i['track']['id'])
id_songs_vivalatino

audio_list_vivalatino =[]
for i in id_songs_vivalatino:
    audio_list_vivalatino.append(sp.audio_features(i)[0])
audio_list_vivalatino

audio_list_vivalatino = pd.DataFrame(audio_list_vivalatino)
audio_list_vivalatino
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.773   0.892    1    -3.732     0       0.0483       0.16600
# 1          0.708   0.737    1    -4.045     1       0.0436       0.07390
# 2          0.652   0.800    9    -4.019     0       0.0614       0.14300
# 3          0.812   0.479    2    -5.678     0       0.3330       0.21300
# 4          0.668   0.758    5    -5.176     0       0.0332       0.48300
# 5          0.859   0.658   11    -4.790     1       0.1590       0.14500
# 6          0.805   0.707    6    -3.758     0       0.0353       0.14200
# 7          0.715   0.642   10    -7.492     0       0.0515       0.06870
# 8          0.557   0.866    6    -4.454     1       0.0503       0.39400
# 9          0.784   0.646   11    -3.626     1       0.0491       0.09780
# 10         0.811   0.771    9    -5.956     0       0.0461       0.00551
# 11         0.681   0.792    1    -4.795     1       0.0587       0.33400
# ...

# %% [markdown]
# #### Baila Reggaeton

# %%
bailareggaeton = sp.search(q="37i9dQZF1DWY7IeIP1cdjF",limit=5,market="GB")
bailareggaeton

selected_playlist_bailareggaeton = get_playlist_tracks('spotify','37i9dQZF1DWY7IeIP1cdjF')
selected_playlist_bailareggaeton

id_songs_bailareggaeton = []
for i in selected_playlist_bailareggaeton:
    id_songs_bailareggaeton.append(i['track']['id'])
id_songs_bailareggaeton

audio_list_bailareggaeton=[]
for i in id_songs_bailareggaeton:
    audio_list_bailareggaeton.append(sp.audio_features(i)[0])
audio_list_bailareggaeton

audio_list_bailareggaeton = pd.DataFrame(audio_list_bailareggaeton)
audio_list_bailareggaeton
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.668   0.712    5    -5.927     1       0.0381       0.36900
# 1          0.720   0.821    6    -2.488     0       0.0681       0.09530
# 2          0.768   0.644    5    -6.671     0       0.1360       0.73600
# 3          0.858   0.691    7    -6.805     0       0.1110       0.02890
# 4          0.708   0.737    1    -4.045     1       0.0436       0.07390
# 5          0.812   0.479    2    -5.678     0       0.3330       0.21300
# 6          0.899   0.833   11    -2.515     0       0.0533       0.42200
# 7          0.859   0.658   11    -4.790     1       0.1590       0.14500
# 8          0.849   0.697   11    -3.799     0       0.0766       0.07840
# 9          0.920   0.696    6    -3.356     0       0.0742       0.18300
# 10         0.750   0.830    0    -3.544     1       0.0683       0.11500
# 11         0.798   0.751    1    -3.464     1       0.1970       0.06540
# ...

# %% [markdown]
# #### Songs to Sing in the Car

# %%
stsitc = sp.search(q="37i9dQZF1DWWMOmoXKqHTD",limit=5,market="GB")
stsitc

selected_playlist_stsitc = get_playlist_tracks('spotify','37i9dQZF1DWWMOmoXKqHTD')
selected_playlist_stsitc

id_songs_stsitc = []
for i in selected_playlist_stsitc:
    id_songs_stsitc.append(i['track']['id'])
id_songs_stsitc

audio_list_stsitc =[]
for i in id_songs_stsitc:
    audio_list_stsitc.append(sp.audio_features(i)[0])
audio_list_stsitc

audio_list_stsitc= pd.DataFrame(audio_list_stsitc)
audio_list_stsitc
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.707   0.681    0    -4.325     1       0.0668       0.06320
# 1          0.637   0.643    4    -6.571     1       0.0519       0.13000
# 2          0.704   0.797    0    -5.927     1       0.0475       0.08260
# 3          0.514   0.730    1    -5.934     1       0.0598       0.00146
# 4          0.445   0.537    4    -8.532     0       0.0400       0.69500
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.667   0.373    4    -9.389     1       0.0500       0.78500
# 96         0.778   0.547    2    -7.273     1       0.0489       0.34600
# 97         0.843   0.806    4    -5.946     0       0.2690       0.14300
# 98         0.771   0.671    2    -5.617     1       0.0553       0.00929
# 99         0.491   0.605    7   -10.098     1       0.0367       0.19200
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### All Out 00s

# %%
allout00 = sp.search(q="7eMpggGjI2UdYxmqMgWzfw",limit=5,market="GB")
allout00

selected_playlist_allout00 = get_playlist_tracks('Fabian Garcia','7eMpggGjI2UdYxmqMgWzfw')
selected_playlist_allout00

id_songs_allout00 = []
for i in selected_playlist_allout00:
    id_songs_allout00.append(i['track']['id'])
id_songs_allout00

audio_list_allout00 =[]
for i in id_songs_allout00:
    audio_list_allout00.append(sp.audio_features(i)[0])
audio_list_allout00

audio_list_allout00 = pd.DataFrame(audio_list_allout00)
audio_list_allout00
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.908   0.669    7    -2.827     1       0.0738       0.00286
# 1           0.722   0.761   11    -4.459     0       0.0475       0.01170
# 2           0.949   0.661    5    -4.244     0       0.0572       0.03020
# 3           0.963   0.298   11    -5.748     0       0.1250       0.01810
# 4           0.791   0.590    1    -9.206     0       0.0793       0.09940
# ..            ...     ...  ...       ...   ...          ...           ...
# 104         0.452   0.574    6    -8.336     1       0.3100       0.24600
# 105         0.637   0.730    5    -5.380     0       0.0874       0.32300
# 106         0.773   0.829    5    -5.763     1       0.0525       0.00211
# 107         0.682   0.795    8    -6.170     0       0.0367       0.02970
# 108         0.707   0.797    7    -7.143     1       0.0435       0.20000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Rock Classics

# %%
rockclassics = sp.search(q="37i9dQZF1DWXRqgorJj26U",limit=5,market="GB")
rockclassics

selected_playlist_rockclassics = get_playlist_tracks('spotify','37i9dQZF1DWXRqgorJj26U')
selected_playlist_rockclassics

id_songs_rockclassics = []
for i in selected_playlist_rockclassics:
    id_songs_rockclassics.append(i['track']['id'])
id_songs_rockclassics

audio_list_rockclassics =[]
for i in id_songs_rockclassics:
    audio_list_rockclassics.append(sp.audio_features(i)[0])
audio_list_rockclassics

audio_list_rockclassics = pd.DataFrame(audio_list_rockclassics)
audio_list_rockclassics
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.464   0.795    1    -9.267     1       0.0926      0.049300
# 1           0.450   0.877    9    -6.403     1       0.0532      0.011800
# 2           0.392   0.476    1    -7.583     1       0.0249      0.397000
# 3           0.215   0.927    9    -7.327     1       0.0452      0.000273
# 4           0.933   0.528    5    -6.472     0       0.1610      0.112000
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.438   0.805    8    -6.237     1       0.0624      0.002550
# 196         0.595   0.996    2    -3.418     1       0.0599      0.195000
# 197         0.617   0.905   11    -4.585     1       0.0351      0.455000
# 198         0.532   0.767    7    -5.509     1       0.0574      0.002870
# 199         0.730   0.487    4   -10.991     1       0.0303      0.258000
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### All Out 80s

# %%
allout80s = sp.search(q="37i9dQZF1DX4UtSsGT1Sbe",limit=5,market="GB")
allout80s

selected_playlist_allout80s = get_playlist_tracks('spotify','37i9dQZF1DX4UtSsGT1Sbe')
selected_playlist_allout80s

id_songs_allout80s = []
for i in selected_playlist_allout80s:
    id_songs_allout80s.append(i['track']['id'])
id_songs_allout80s

audio_list_allout80s =[]
for i in id_songs_allout80s:
    audio_list_allout80s.append(sp.audio_features(i)[0])
audio_list_allout80s

audio_list_allout80s = pd.DataFrame(audio_list_allout80s)
audio_list_allout80s
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.724   0.436    0    -9.321     1       0.0282        0.5760
# 1           0.645   0.795    7   -12.095     1       0.0527        0.3470
# 2           0.573   0.902    6    -7.638     0       0.0540        0.0180
# 3           0.446   0.952    6    -5.321     1       0.0523        0.0901
# 4           0.532   0.887    0    -3.757     1       0.0335        0.0778
# ..            ...     ...  ...       ...   ...          ...           ...
# 145         0.491   0.802    4    -7.106     1       0.0392        0.2500
# 146         0.653   0.677    0   -12.244     1       0.0396        0.2490
# 147         0.720   0.828    5    -9.211     1       0.0462        0.1850
# 148         0.658   0.575   11   -10.365     1       0.0267        0.2430
# 149         0.671   0.712    2    -7.815     1       0.0476        0.4290
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Beast Mode

# %%
beastmode = sp.search(q="37i9dQZF1DX76Wlfdnj7AP",limit=5,market="GB")
beastmode

selected_playlist_beastmode = get_playlist_tracks('spotify','37i9dQZF1DX76Wlfdnj7AP')
selected_playlist_beastmode

id_songs_beastmode = []
for i in selected_playlist_beastmode:
    id_songs_beastmode.append(i['track']['id'])
id_songs_beastmode

audio_list_beastmode =[]
for i in id_songs_beastmode:
    audio_list_beastmode.append(sp.audio_features(i)[0])
audio_list_beastmode

audio_list_beastmode = pd.DataFrame(audio_list_beastmode)
audio_list_beastmode
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.561   0.965    7    -3.673     0       0.0343       0.00383
# 1           0.696   0.809    5    -8.254     1       0.0500       0.25200
# 2           0.621   0.782    2    -5.548     1       0.0440       0.01250
# 3           0.911   0.712    1    -5.105     0       0.0817       0.09010
# 4           0.683   0.764    2    -5.995     1       0.0441       0.04270
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.783   0.853   11    -4.787     1       0.2920       0.25200
# 196         0.833   0.848    2    -6.104     1       0.2680       0.01930
# 197         0.911   0.667    1    -6.606     1       0.2770       0.03130
# 198         0.651   0.783    0    -6.162     1       0.0501       0.04500
# 199         0.738   0.651   10    -7.511     0       0.2890       0.07300
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### All Out 90s

# %%
allout90s = sp.search(q="37i9dQZF1DXbTxeAdrVG2l",limit=5,market="GB")
rapcaviar

selected_playlist_allout90s = get_playlist_tracks('spotify','37i9dQZF1DXbTxeAdrVG2l')
selected_playlist_allout90s

id_songs_allout90s = []
for i in selected_playlist_allout90s:
    id_songs_allout90s.append(i['track']['id'])
id_songs_allout90s

audio_list_allout90s =[]
for i in id_songs_allout90s:
    audio_list_allout90s.append(sp.audio_features(i)[0])
audio_list_allout90s

audio_list_allout90s = pd.DataFrame(audio_list_allout90s)
audio_list_allout90s
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.769   0.505    1    -7.345     1       0.0829      0.311000
# 1           0.515   0.430    7    -9.935     1       0.0372      0.009700
# 2           0.647   0.514    8   -10.050     1       0.0593      0.065500
# 3           0.666   0.855    9    -5.051     0       0.0295      0.179000
# 4           0.502   0.890    4    -5.175     1       0.0364      0.000147
# ..            ...     ...  ...       ...   ...          ...           ...
# 145         0.490   0.873    6    -5.861     1       0.0355      0.107000
# 146         0.831   0.735    0    -6.254     0       0.0384      0.003970
# 147         0.650   0.820    5   -10.900     0       0.0356      0.066200
# 148         0.615   0.419   11    -8.800     0       0.0395      0.017300
# 149         0.729   0.936    9    -7.536     1       0.0776      0.012900
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Chill Hits

# %%
chillhits = sp.search(q="37i9dQZF1DX4WYpdgoIcn6",limit=5,market="GB")
chillhits

selected_playlist_chillhits = get_playlist_tracks('spotify','37i9dQZF1DX4WYpdgoIcn6')
selected_playlist_chillhits

id_songs_chillhits = []
for i in selected_playlist_chillhits:
    id_songs_chillhits.append(i['track']['id'])
id_songs_chillhits

audio_list_chillhits =[]
for i in id_songs_chillhits:
    audio_list_chillhits.append(sp.audio_features(i)[0])
audio_list_chillhits

audio_list_chillhits = pd.DataFrame(audio_list_chillhits)
audio_list_chillhits
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.508   0.430    2    -9.475     0       0.0335        0.8300
# 1           0.573   0.422   10    -7.621     0       0.0678        0.5510
# 2           0.551   0.550   10    -5.339     1       0.0286        0.7770
# 3           0.761   0.525   11    -6.900     1       0.0944        0.4400
# 4           0.490   0.352    6   -11.577     0       0.0254        0.7090
# ..            ...     ...  ...       ...   ...          ...           ...
# 125         0.442   0.517    9    -7.807     1       0.0548        0.0699
# 126         0.679   0.408    4    -9.754     0       0.0882        0.1330
# 127         0.483   0.321   10   -10.401     0       0.0719        0.8200
# 128         0.697   0.535    4    -6.504     1       0.0680        0.2470
# 129         0.587   0.267    8    -9.206     1       0.0349        0.8400
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Peaceful Piano

# %%
peacefulpiano = sp.search(q="37i9dQZF1DX4WYpdgoIcn6",limit=5,market="GB")
peacefulpiano

selected_playlist_peacefulpiano = get_playlist_tracks('spotify','37i9dQZF1DX4WYpdgoIcn6')
selected_playlist_peacefulpiano

id_songs_peacefulpiano = []
for i in selected_playlist_peacefulpiano:
    id_songs_peacefulpiano.append(i['track']['id'])
id_songs_peacefulpiano

audio_list_peacefulpiano =[]
for i in id_songs_peacefulpiano:
    audio_list_peacefulpiano.append(sp.audio_features(i)[0])
audio_list_peacefulpiano

audio_list_peacefulpiano = pd.DataFrame(audio_list_peacefulpiano)
audio_list_peacefulpiano
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.508   0.430    2    -9.475     0       0.0335        0.8300
# 1           0.573   0.422   10    -7.621     0       0.0678        0.5510
# 2           0.551   0.550   10    -5.339     1       0.0286        0.7770
# 3           0.761   0.525   11    -6.900     1       0.0944        0.4400
# 4           0.490   0.352    6   -11.577     0       0.0254        0.7090
# ..            ...     ...  ...       ...   ...          ...           ...
# 125         0.442   0.517    9    -7.807     1       0.0548        0.0699
# 126         0.679   0.408    4    -9.754     0       0.0882        0.1330
# 127         0.483   0.321   10   -10.401     0       0.0719        0.8200
# 128         0.697   0.535    4    -6.504     1       0.0680        0.2470
# 129         0.587   0.267    8    -9.206     1       0.0349        0.8400
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Hot Country

# %%
hotcountry = sp.search(q="37i9dQZF1DX1lVhptIYRda",limit=5,market="GB")
hotcountry

selected_playlist_hotcountry = get_playlist_tracks('spotify','37i9dQZF1DX1lVhptIYRda')
selected_playlist_hotcountry

id_songs_hotcountry = []
for i in selected_playlist_hotcountry:
    id_songs_hotcountry.append(i['track']['id'])
id_songs_hotcountry

audio_list_hotcountry =[]
for i in id_songs_hotcountry:
    audio_list_hotcountry.append(sp.audio_features(i)[0])
audio_list_hotcountry

audio_list_hotcountry = pd.DataFrame(audio_list_hotcountry)
audio_list_hotcountry
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.712   0.603    8    -5.520     1       0.0262      0.186000
# 1          0.667   0.671    1    -4.200     0       0.0496      0.413000
# 2          0.657   0.871    7    -4.614     1       0.0675      0.003100
# 3          0.459   0.682    8    -4.235     1       0.0464      0.167000
# 4          0.563   0.755    5    -4.504     1       0.0253      0.013400
# 5          0.517   0.675    6    -5.382     1       0.0357      0.459000
# 6          0.647   0.776    7    -5.221     1       0.0514      0.006860
# 7          0.552   0.774   10    -3.685     1       0.0401      0.215000
# 8          0.461   0.887   11    -4.871     0       0.0429      0.000219
# 9          0.524   0.806    4    -5.785     1       0.0522      0.052100
# 10         0.570   0.670    1    -6.519     1       0.0274      0.426000
# 11         0.531   0.623    1    -5.316     1       0.0347      0.050600
# ...

# %% [markdown]
# #### Get Turnt

# %%
getturnt = sp.search(q="37i9dQZF1DWY4xHQp97fN6",limit=5,market="GB")
getturnt

selected_playlist_getturnt = get_playlist_tracks('spotify','37i9dQZF1DWY4xHQp97fN6')
selected_playlist_getturnt

id_songs_getturnt = []
for i in selected_playlist_getturnt:
    id_songs_getturnt.append(i['track']['id'])
id_songs_getturnt

audio_list_getturnt =[]
for i in id_songs_getturnt:
    audio_list_getturnt.append(sp.audio_features(i)[0])
audio_list_getturnt

audio_list_getturnt = pd.DataFrame(audio_list_getturnt)
audio_list_getturnt
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.818   0.510    2    -7.050     0       0.4080      0.209000
# 1          0.911   0.536    4    -7.884     0       0.2820      0.008970
# 2          0.847   0.622    1    -6.747     0       0.0903      0.119000
# 3          0.971   0.671   10    -5.260     0       0.1540      0.416000
# 4          0.773   0.607   10    -6.768     0       0.3820      0.035400
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.817   0.512    8    -6.943     1       0.0984      0.037000
# 96         0.660   0.373   11   -10.234     1       0.5950      0.149000
# 97         0.529   0.673    0    -4.711     1       0.1750      0.000307
# 98         0.906   0.807    2    -4.401     1       0.2940      0.177000
# 99         0.830   0.644   10    -5.431     0       0.4070      0.029800
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Mood Booster

# %%
moodbooster = sp.search(q="37i9dQZF1DX3rxVfibe1L0",limit=5,market="GB")
moodbooster

selected_playlist_moodbooster = get_playlist_tracks('spotify','37i9dQZF1DX3rxVfibe1L0')
selected_playlist_moodbooster

id_songs_moodbooster = []
for i in selected_playlist_moodbooster:
    id_songs_moodbooster.append(i['track']['id'])
id_songs_moodbooster

audio_list_moodbooster =[]
for i in id_songs_moodbooster:
    audio_list_moodbooster.append(sp.audio_features(i)[0])
audio_list_moodbooster

audio_list_moodbooster = pd.DataFrame(audio_list_moodbooster)
audio_list_moodbooster
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.552   0.702    9    -5.707     1       0.1570       0.11700
# 1          0.707   0.681    0    -4.325     1       0.0668       0.06320
# 2          0.561   0.965    7    -3.673     0       0.0343       0.00383
# 3          0.801   0.806   11    -5.206     1       0.0381       0.38200
# 4          0.704   0.797    0    -5.927     1       0.0475       0.08260
# ..           ...     ...  ...       ...   ...          ...           ...
# 71         0.745   0.729    4    -5.573     0       0.2210       0.05580
# 72         0.675   0.793    2    -6.000     1       0.1570       0.10800
# 73         0.812   0.706    4    -6.054     0       0.0709       0.04120
# 74         0.689   0.706    1    -4.480     0       0.0312       0.08330
# 75         0.935   0.810   11    -3.838     0       0.1170       0.04010
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Songs to Sing in the Shower

# %%
stsits = sp.search(q="37i9dQZF1DWSqmBTGDYngZ",limit=5,market="GB")
stsits

selected_playlist_stsits = get_playlist_tracks('spotify','37i9dQZF1DWSqmBTGDYngZ')
selected_playlist_stsits

id_songs_stsits = []
for i in selected_playlist_stsits:
    id_songs_stsits.append(i['track']['id'])
id_songs_stsits

audio_list_stsits =[]
for i in id_songs_stsits:
    audio_list_stsits.append(sp.audio_features(i)[0])
audio_list_stsits

audio_list_stsits = pd.DataFrame(audio_list_stsits)
audio_list_stsits
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.552   0.702    9    -5.707     1       0.1570       0.11700
# 1           0.561   0.965    7    -3.673     0       0.0343       0.00383
# 2           0.704   0.797    0    -5.927     1       0.0475       0.08260
# 3           0.514   0.730    1    -5.934     1       0.0598       0.00146
# 4           0.429   0.661   11    -7.227     1       0.0281       0.00239
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.599   0.785    3    -4.013     1       0.0309       0.44800
# 196         0.491   0.588    1    -6.177     1       0.0506       0.02810
# 197         0.700   0.864    7    -3.629     1       0.0283       0.02120
# 198         0.508   0.720   11    -5.908     0       0.0628       0.27200
# 199         0.798   0.625   11    -9.689     1       0.0548       0.00547
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### mint

# %%
mint = sp.search(q="37i9dQZF1DX4dyzvuaRJ0n",limit=5,market="GB")
mint

selected_playlist_mint = get_playlist_tracks('spotify','37i9dQZF1DX4dyzvuaRJ0n')
selected_playlist_mint

id_songs_mint = []
for i in selected_playlist_mint:
    id_songs_mint.append(i['track']['id'])
id_songs_mint

audio_list_mint =[]
for i in id_songs_mint:
    audio_list_mint.append(sp.audio_features(i)[0])
audio_list_mint

audio_list_mint = pd.DataFrame(audio_list_mint)
audio_list_mint
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.671   0.876    7    -5.681     0       0.0352      0.120000
# 1          0.883   0.708    1    -6.609     1       0.2020      0.000521
# 2          0.807   0.685   11    -7.365     0       0.0502      0.008040
# 3          0.738   0.883    8    -7.989     1       0.0818      0.053000
# 4          0.712   0.882    8    -4.691     0       0.0782      0.038400
# ..           ...     ...  ...       ...   ...          ...           ...
# 70         0.747   0.616    3    -9.760     0       0.0324      0.176000
# 71         0.660   0.878    6    -6.647     0       0.0596      0.212000
# 72         0.735   0.651    7    -9.250     0       0.1120      0.329000
# 73         0.589   0.808    2    -4.338     0       0.0848      0.265000
# 74         0.688   0.809   10    -4.781     0       0.0474      0.069400
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Esquenta Sertanejo

# %%
esquentasertanejo = sp.search(q="37i9dQZF1DXdSjVZQzv2tl",limit=5,market="GB")
esquentasertanejo

selected_playlist_esquentasertanejo = get_playlist_tracks('spotify','37i9dQZF1DXdSjVZQzv2tl')
selected_playlist_esquentasertanejo

id_songs_esquentasertanejo = []
for i in selected_playlist_esquentasertanejo:
    id_songs_esquentasertanejo.append(i['track']['id'])
id_songs_esquentasertanejo

audio_list_esquentasertanejo =[]
for i in id_songs_esquentasertanejo:
    audio_list_esquentasertanejo.append(sp.audio_features(i)[0])
audio_list_esquentasertanejo

audio_list_esquentasertanejo = pd.DataFrame(audio_list_esquentasertanejo)
audio_list_esquentasertanejo
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.700   0.877   11    -3.952     0       0.1030        0.4840
# 1          0.625   0.916    6    -3.704     1       0.0461        0.3090
# 2          0.588   0.893    6    -2.743     1       0.0866        0.1760
# 3          0.483   0.910   11    -3.474     1       0.0845        0.1300
# 4          0.670   0.668    2    -6.411     1       0.0459        0.6010
# 5          0.736   0.818    8    -4.605     1       0.0830        0.1480
# 6          0.689   0.710    9    -4.822     1       0.1960        0.3300
# 7          0.483   0.954    9    -4.786     1       0.1800        0.1300
# 8          0.603   0.808   11    -5.768     1       0.0506        0.4550
# 9          0.656   0.842    5    -3.746     0       0.2010        0.5740
# 10         0.743   0.865    6    -3.897     1       0.0315        0.4490
# 11         0.479   0.645    3    -7.058     0       0.0425        0.6420
# ...

# %% [markdown]
# #### Happy Hits!

# %%
happyhits = sp.search(q="37i9dQZF1DXdPec7aLTmlC",limit=5,market="GB")
happyhits

selected_playlist_happyhits = get_playlist_tracks('spotify','37i9dQZF1DXdPec7aLTmlC')
selected_playlist_happyhits

id_songs_happyhits = []
for i in selected_playlist_happyhits:
    id_songs_happyhits.append(i['track']['id'])
id_songs_happyhits

audio_list_happyhits =[]
for i in id_songs_happyhits:
    audio_list_happyhits.append(sp.audio_features(i)[0])
audio_list_happyhits

audio_list_happyhits = pd.DataFrame(audio_list_happyhits)
audio_list_happyhits
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.561   0.965    7    -3.673     0       0.0343       0.00383
# 1          0.704   0.797    0    -5.927     1       0.0475       0.08260
# 2          0.514   0.730    1    -5.934     1       0.0598       0.00146
# 3          0.671   0.845   11    -4.930     0       0.0480       0.02070
# 4          0.548   0.816    0    -4.209     1       0.0465       0.12200
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.672   0.855    9    -3.764     1       0.0397       0.02100
# 96         0.862   0.753    5    -5.356     1       0.0625       0.13100
# 97         0.643   0.585    2    -5.994     1       0.0369       0.22500
# 98         0.464   0.724    7    -5.019     1       0.0705       0.01880
# 99         0.729   0.786   10    -4.357     1       0.0389       0.11700
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### Cross-Genre Mix

# %%
crossgenre = sp.search(q="37i9dQZF1EIgralXNNoOAg",limit=5,market="GB")
crossgenre

selected_playlist_crossgenre = get_playlist_tracks('spotify','37i9dQZF1EIgralXNNoOAg')
selected_playlist_crossgenre

id_songs_crossgenre = []
for i in selected_playlist_crossgenre:
    id_songs_crossgenre.append(i['track']['id'])
id_songs_crossgenre

audio_list_crossgenre =[]
for i in id_songs_crossgenre:
    audio_list_crossgenre.append(sp.audio_features(i)[0])
audio_list_crossgenre

audio_list_crossgenre = pd.DataFrame(audio_list_crossgenre)
audio_list_crossgenre
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.598  0.3840    1   -13.523     1       0.1940      0.556000
# 1          0.385  0.9040    6    -6.081     0       0.1270      0.002730
# 2          0.615  0.9990   11    -5.334     1       0.3580      0.002870
# 3          0.480  0.8800    9    -7.030     1       0.0484      0.134000
# 4          0.661  0.8140    5    -4.290     0       0.0317      0.014600
# 5          0.479  0.9420    5    -3.074     1       0.0611      0.167000
# 6          0.704  0.9100    0    -3.363     1       0.0906      0.446000
# 7          0.748  0.5880    3    -8.508     1       0.0484      0.663000
# 8          0.210  0.6170    4   -15.142     1       0.0409      0.000011
# 9          0.795  0.6620    1    -3.005     1       0.0458      0.000204
# 10         0.672  0.7380    9    -4.130     0       0.2600      0.231000
# 11         0.878  0.4180   10    -5.961     0       0.1170      0.441000
# ...

# %% [markdown]
# #### Multi-Genre Mix

# %%
multigenre = sp.search(q="37i9dQZF1EIcWrg7lBT2vk",limit=5,market="GB")
multigenre

selected_playlist_multigenre = get_playlist_tracks('spotify','37i9dQZF1EIcWrg7lBT2vk')
selected_playlist_multigenre

id_songs_multigenre = []
for i in selected_playlist_multigenre:
    id_songs_multigenre.append(i['track']['id'])
id_songs_multigenre

audio_list_multigenre =[]
for i in id_songs_multigenre:
    audio_list_multigenre.append(sp.audio_features(i)[0])
audio_list_multigenre

audio_list_multigenre = pd.DataFrame(audio_list_multigenre)
audio_list_multigenre
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0         0.2520   0.790    9    -4.923     0       0.0763      0.065800
# 1         0.5490   0.117    3   -11.578     1       0.0295      0.966000
# 2         0.7990   0.614    2    -9.369     1       0.0889      0.099300
# 3         0.7160   0.764    0    -5.146     1       0.0692      0.017800
# 4         0.5400   0.377    5    -7.549     1       0.0269      0.893000
# 5         0.4580   0.931    7    -1.293     1       0.2430      0.011000
# 6         0.3420   0.588    0    -5.265     0       0.0404      0.154000
# 7         0.6380   0.466    6   -13.167     1       0.0536      0.477000
# 8         0.4180   0.508    4    -7.142     1       0.0275      0.235000
# 9         0.5380   0.471    9   -14.946     1       0.0343      0.525000
# 10        0.5250   0.826    7    -3.512     1       0.0345      0.194000
# 11        0.4780   0.938    4    -5.848     1       0.1310      0.021100
# ...

# %% [markdown]
# #### Dancehall Official

# %%
dancehall = sp.search(q="37i9dQZF1DXan38dNVDdl4",limit=5,market="GB")
dancehall

selected_playlist_dancehall = get_playlist_tracks('spotify','37i9dQZF1DX4dyzvuaRJ0n')
selected_playlist_dancehall

id_songs_dancehall = []
for i in selected_playlist_dancehall:
    id_songs_dancehall.append(i['track']['id'])
id_songs_dancehall

audio_list_dancehall =[]
for i in id_songs_dancehall:
    audio_list_dancehall.append(sp.audio_features(i)[0])
audio_list_dancehall

audio_list_dancehall = pd.DataFrame(audio_list_dancehall)
audio_list_dancehall
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.671   0.876    7    -5.681     0       0.0352      0.120000
# 1          0.883   0.708    1    -6.609     1       0.2020      0.000521
# 2          0.807   0.685   11    -7.365     0       0.0502      0.008040
# 3          0.738   0.883    8    -7.989     1       0.0818      0.053000
# 4          0.712   0.882    8    -4.691     0       0.0782      0.038400
# ..           ...     ...  ...       ...   ...          ...           ...
# 70         0.747   0.616    3    -9.760     0       0.0324      0.176000
# 71         0.660   0.878    6    -6.647     0       0.0596      0.212000
# 72         0.735   0.651    7    -9.250     0       0.1120      0.329000
# 73         0.589   0.808    2    -4.338     0       0.0848      0.265000
# 74         0.688   0.809   10    -4.781     0       0.0474      0.069400
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### african heat

# %%
africanheat = sp.search(q="37i9dQZF1DWYkaDif7Ztbp",limit=5,market="GB")
africanheat

selected_playlist_africanheat = get_playlist_tracks('spotify','37i9dQZF1DWYkaDif7Ztbp')
selected_playlist_africanheat

id_songs_africanheat= []
for i in selected_playlist_africanheat:
    id_songs_africanheat.append(i['track']['id'])
id_songs_africanheat

audio_list_africanheat =[]
for i in id_songs_africanheat:
    audio_list_africanheat.append(sp.audio_features(i)[0])
audio_list_africanheat

audio_list_africanheat= pd.DataFrame(audio_list_africanheat)
audio_list_africanheat
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.788   0.649    2    -9.674     1       0.0532       0.25300
# 1          0.711   0.725    3    -8.315     0       0.0941       0.42400
# 2          0.826   0.657    5    -7.779     0       0.1470       0.20400
# 3          0.719   0.756    5    -5.392     0       0.0761       0.05410
# 4          0.861   0.715    9    -3.769     0       0.0496       0.18600
# 5          0.828   0.726   10    -6.389     0       0.0419       0.10600
# 6          0.724   0.809    6    -5.022     0       0.0929       0.18200
# 7          0.768   0.663    4    -6.901     0       0.0355       0.58100
# 8          0.792   0.503    1    -8.044     1       0.0626       0.03690
# 9          0.842   0.504    1    -7.557     1       0.0534       0.02460
# 10         0.628   0.795   10    -6.270     0       0.0366       0.04440
# 11         0.845   0.609    9    -6.498     1       0.0401       0.08050
# ...

# %% [markdown]
# #### soft pop

# %%
softpop = sp.search(q="37i9dQZF1DWTwnEm1IYyoj",limit=5,market="GB")
softpop

selected_playlist_softpop = get_playlist_tracks('spotify','37i9dQZF1DWTwnEm1IYyoj')
selected_playlist_softpop

id_songs_softpop = []
for i in selected_playlist_softpop:
    id_songs_softpop.append(i['track']['id'])
id_songs_softpop

audio_list_softpop =[]
for i in id_songs_softpop:
    audio_list_softpop.append(sp.audio_features(i)[0])
audio_list_softpop

audio_list_softpop = pd.DataFrame(audio_list_softpop)
audio_list_softpop
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.704   0.797    0    -5.927     1       0.0475        0.0826
# 1          0.468   0.779    9    -4.839     1       0.0779        0.1120
# 2          0.422   0.264    8    -7.064     1       0.0322        0.9220
# 3          0.604   0.366    5    -7.519     1       0.0282        0.5780
# 4          0.677   0.485    5    -5.795     1       0.0361        0.5290
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.555   0.717    2    -5.114     1       0.0269        0.0414
# 96         0.505   0.710    3    -3.015     1       0.0321        0.1900
# 97         0.664   0.705    1    -4.972     0       0.0382        0.0654
# 98         0.728   0.415    8    -6.852     1       0.0639        0.4010
# 99         0.494   0.632    5    -6.890     1       0.0342        0.6820
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### workout twerkout

# %%
workouttwerkout = sp.search(q="37i9dQZF1DX0HRj9P7NxeE",limit=5,market="GB")
workouttwerkout

selected_playlist_workouttwerkout = get_playlist_tracks('spotify','37i9dQZF1DX0HRj9P7NxeE')
selected_playlist_workouttwerkout

id_songs_workouttwerkout = []
for i in selected_playlist_workouttwerkout:
    id_songs_workouttwerkout.append(i['track']['id'])
id_songs_workouttwerkout

audio_list_workouttwerkout =[]
for i in id_songs_workouttwerkout:
    audio_list_workouttwerkout.append(sp.audio_features(i)[0])
audio_list_workouttwerkout

audio_list_workouttwerkout = pd.DataFrame(audio_list_workouttwerkout)
audio_list_workouttwerkout
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.696   0.809    5    -8.254     1       0.0500       0.25200
# 1          0.954   0.516    6    -5.817     1       0.1600       0.03000
# 2          0.912   0.655    8    -6.029     0       0.1620       0.31500
# 3          0.849   0.614    1    -7.323     1       0.3170       0.02820
# 4          0.856   0.513    2    -7.912     1       0.0605       0.01090
# 5          0.795   0.814    0    -3.945     1       0.4000       0.07360
# 6          0.637   0.634    2    -8.126     1       0.4260       0.17400
# 7          0.792   0.919    2    -5.688     1       0.2760       0.03810
# 8          0.903   0.535    9    -6.434     1       0.0742       0.29700
# 9          0.898   0.676    9    -5.196     1       0.1870       0.14000
# 10         0.792   0.874    1    -2.966     1       0.0852       0.01580
# 11         0.953   0.621   11    -7.565     1       0.1540       0.00799
# ...

# %% [markdown]
# #### you and me

# %%
youandme = sp.search(q="37i9dQZF1DX6mvEU1S6INL",limit=5,market="GB")
youandme

selected_playlist_youandme = get_playlist_tracks('spotify','37i9dQZF1DX6mvEU1S6INL')

id_songs_youandme = []
for i in selected_playlist_youandme:
    id_songs_youandme.append(i['track']['id'])
id_songs_youandme

audio_list_youandme =[]
for i in id_songs_youandme:
    audio_list_youandme.append(sp.audio_features(i)[0])
audio_list_youandme

audio_list_youandme = pd.DataFrame(audio_list_youandme)
audio_list_youandme
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.668   0.902    2    -3.924     1       0.0386       0.16900
# 1          0.604   0.789    5    -6.259     1       0.0273       0.00110
# 2          0.464   0.417    0    -9.345     0       0.0256       0.13600
# 3          0.761   0.525   11    -6.900     1       0.0944       0.44000
# 4          0.346   0.500   10    -6.097     1       0.0388       0.75700
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.396   0.682    8   -10.828     1       0.0356       0.00588
# 96         0.585   0.442   11   -10.478     1       0.0294       0.89600
# 97         0.577   0.687    0    -6.389     1       0.0365       0.13300
# 98         0.475   0.765    0    -5.914     0       0.0455       0.23900
# 99         0.580   0.354    0    -9.298     1       0.0264       0.06270
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### rock solid

# %%
rocksolid = sp.search(q="37i9dQZF1DX49jUV2NfGku",limit=5,market="GB")
rocksolid

selected_playlist_rocksolid = get_playlist_tracks('spotify','37i9dQZF1DX49jUV2NfGku')
selected_playlist_rocksolid

id_songs_rocksolid = []
for i in selected_playlist_rocksolid:
    id_songs_rocksolid.append(i['track']['id'])
id_songs_rocksolid

audio_list_rocksolid =[]
for i in id_songs_rocksolid:
    audio_list_rocksolid.append(sp.audio_features(i)[0])
audio_list_rocksolid

audio_list_rocksolid = pd.DataFrame(audio_list_rocksolid)
audio_list_rocksolid
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.417   0.934    7    -3.908     0       0.1190      0.000278
# 1          0.456   0.831    9    -4.589     1       0.0417      0.000700
# 2          0.433   0.959    9    -4.040     1       0.0431      0.000917
# 3          0.743   0.446    4    -7.807     0       0.0683      0.003900
# 4          0.466   0.833    7    -4.215     1       0.3040      0.026600
# ..           ...     ...  ...       ...   ...          ...           ...
# 70         0.582   0.962    4    -3.037     1       0.0542      0.009600
# 71         0.509   0.774    6    -4.054     1       0.0338      0.001890
# 72         0.502   0.758    3    -9.760     1       0.0407      0.009150
# 73         0.468   0.851   11    -3.617     1       0.0398      0.000281
# 74         0.673   0.899   11    -3.528     1       0.0434      0.091100
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### soak up the sun

# %%
soakupthesun = sp.search(q="37i9dQZF1DX6ALfRKlHn1t",limit=5,market="GB")
soakupthesun

selected_playlist_soakupthesun = get_playlist_tracks('spotify','37i9dQZF1DX6ALfRKlHn1t')
selected_playlist_soakupthesun

id_songs_soakupthesun = []
for i in selected_playlist_soakupthesun:
    id_songs_soakupthesun.append(i['track']['id'])
id_songs_soakupthesun

audio_list_soakupthesun =[]
for i in id_songs_soakupthesun:
    audio_list_soakupthesun.append(sp.audio_features(i)[0])
audio_list_soakupthesun

audio_list_soakupthesun = pd.DataFrame(audio_list_soakupthesun)
audio_list_soakupthesun
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.624   0.718    1    -5.946     1       0.0312      0.043600
# 1          0.523   0.846    6    -4.749     0       0.0563      0.201000
# 2          0.751   0.720    4    -6.376     1       0.0303      0.554000
# 3          0.761   0.525   11    -6.900     1       0.0944      0.440000
# 4          0.633   0.684   10    -4.314     0       0.5910      0.314000
# ..           ...     ...  ...       ...   ...          ...           ...
# 70         0.743   0.670    1    -4.547     0       0.0293      0.010800
# 71         0.742   0.546    1    -7.694     1       0.0315      0.172000
# 72         0.803   0.636    2    -6.456     1       0.0464      0.008550
# 73         0.471   0.773    9    -6.862     1       0.0478      0.142000
# 74         0.451   0.970    0    -4.858     1       0.0605      0.000372
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### wild country

# %%
wildcountry = sp.search(q="37i9dQZF1DX5mB2C8gBeUM",limit=5,market="GB")
wildcountry

selected_playlist_wildcountry = get_playlist_tracks('spotify','37i9dQZF1DX5mB2C8gBeUM')
selected_playlist_wildcountry

id_songs_wildcountry = []
for i in selected_playlist_wildcountry:
    id_songs_wildcountry.append(i['track']['id'])
id_songs_wildcountry

audio_list_wildcountry =[]
for i in id_songs_wildcountry:
    audio_list_wildcountry.append(sp.audio_features(i)[0])
audio_list_wildcountry

audio_list_wildcountry = pd.DataFrame(audio_list_wildcountry)
audio_list_wildcountry
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.659   0.568    0    -5.198     1       0.0896       0.02810
# 1           0.426   0.811    6    -4.622     1       0.0397       0.00324
# 2           0.731   0.872    9    -3.715     1       0.0685       0.36700
# 3           0.547   0.743    1    -4.997     0       0.0454       0.16000
# 4           0.643   0.285    1   -17.533     1       0.1120       0.18300
# ..            ...     ...  ...       ...   ...          ...           ...
# 133         0.414   0.690    7    -6.917     1       0.0355       0.00459
# 134         0.477   0.892    7    -3.504     0       0.0551       0.17400
# 135         0.649   0.842    4    -5.296     0       0.0432       0.01280
# 136         0.498   0.590    7    -6.138     1       0.0333       0.13100
# 137         0.407   0.818    0    -5.755     1       0.1760       0.41100
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### 90s country

# %%
country90s = sp.search(q="37i9dQZF1DWVpjAJGB70vU",limit=5,market="GB")
country90s

selected_playlist_country90s = get_playlist_tracks('spotify','37i9dQZF1DWVpjAJGB70vU')
selected_playlist_country90s

id_songs_country90s = []
for i in selected_playlist_mint:
    id_songs_country90s.append(i['track']['id'])
id_songs_country90s

audio_list_country90s =[]
for i in id_songs_country90s:
    audio_list_country90s.append(sp.audio_features(i)[0])
audio_list_country90s

audio_list_country90s = pd.DataFrame(audio_list_country90s)
audio_list_country90s
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.671   0.876    7    -5.681     0       0.0352      0.120000
# 1          0.883   0.708    1    -6.609     1       0.2020      0.000521
# 2          0.807   0.685   11    -7.365     0       0.0502      0.008040
# 3          0.738   0.883    8    -7.989     1       0.0818      0.053000
# 4          0.712   0.882    8    -4.691     0       0.0782      0.038400
# ..           ...     ...  ...       ...   ...          ...           ...
# 70         0.747   0.616    3    -9.760     0       0.0324      0.176000
# 71         0.660   0.878    6    -6.647     0       0.0596      0.212000
# 72         0.735   0.651    7    -9.250     0       0.1120      0.329000
# 73         0.589   0.808    2    -4.338     0       0.0848      0.265000
# 74         0.688   0.809   10    -4.781     0       0.0474      0.069400
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### soul lounge

# %%
soullounge = sp.search(q="37i9dQZF1DX62Nfha2yFhL",limit=5,market="GB")
soullounge

selected_playlist_soullounge = get_playlist_tracks('spotify','37i9dQZF1DX62Nfha2yFhL')
selected_playlist_soullounge

id_songs_soullounge = []
for i in selected_playlist_soullounge:
    id_songs_soullounge.append(i['track']['id'])
id_songs_soullounge

audio_list_soullounge =[]
for i in id_songs_soullounge:
    audio_list_soullounge.append(sp.audio_features(i)[0])
audio_list_soullounge

audio_list_soullounge = pd.DataFrame(audio_list_soullounge)
audio_list_soullounge
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.569   0.724   11    -5.404     0       0.0246        0.1340
# 1           0.850   0.538    7    -4.380     1       0.3720        0.1250
# 2           0.570   0.717    0    -9.350     1       0.2330        0.1400
# 3           0.738   0.864    5    -5.110     1       0.0695        0.0757
# 4           0.678   0.582    1    -9.844     1       0.0325        0.2150
# ..            ...     ...  ...       ...   ...          ...           ...
# 101         0.669   0.352    1   -11.180     1       0.4550        0.3220
# 102         0.771   0.889    7    -7.930     1       0.0777        0.0779
# 103         0.747   0.412    1    -6.122     1       0.0379        0.4480
# 104         0.732   0.886    6    -5.445     0       0.0994        0.2390
# 105         0.868   0.580    5    -9.575     0       0.2760        0.7130
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### funk outta here

# %%
funk = sp.search(q="37i9dQZF1DX70TzPK5buVf",limit=5,market="GB")
funk

selected_playlist_funk = get_playlist_tracks('spotify','37i9dQZF1DX70TzPK5buVf')
selected_playlist_funk

id_songs_funk = []
for i in selected_playlist_funk:
    id_songs_funk.append(i['track']['id'])
id_songs_funk

audio_list_funk =[]
for i in id_songs_funk:
    audio_list_funk.append(sp.audio_features(i)[0])
audio_list_funk

audio_list_funk = pd.DataFrame(audio_list_funk)
audio_list_funk
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.814   0.672    9   -12.068     1       0.0619       0.04350
# 1          0.856   0.609    0    -7.223     1       0.0824       0.00801
# 2          0.877   0.560    7    -8.529     1       0.0621       0.15600
# 3          0.687   0.630    6   -10.817     1       0.0389       0.25100
# 4          0.838   0.794    9    -8.245     0       0.0531       0.22000
# ..           ...     ...  ...       ...   ...          ...           ...
# 75         0.734   0.586    2   -11.866     1       0.1290       0.12500
# 76         0.793   0.772   11    -7.280     0       0.1460       0.06190
# 77         0.804   0.866    1    -8.829     0       0.1040       0.43400
# 78         0.868   0.671    7   -10.284     1       0.0393       0.05140
# 79         0.784   0.708    2    -9.141     1       0.1100       0.45700
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### deep house

# %%
deephouse = sp.search(q="37i9dQZF1DX2TRYkJECvfC",limit=5,market="GB")
deephouse

selected_playlist_deephouse = get_playlist_tracks('spotify','37i9dQZF1DX2TRYkJECvfC')
selected_playlist_deephouse

id_songs_deephouse = []
for i in selected_playlist_deephouse:
    id_songs_deephouse.append(i['track']['id'])
id_songs_deephouse

audio_list_deephouse =[]
for i in id_songs_deephouse:
    audio_list_deephouse.append(sp.audio_features(i)[0])
audio_list_deephouse

audio_list_deephouse = pd.DataFrame(audio_list_deephouse)
audio_list_deephouse
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.762   0.942    9    -6.432     0       0.0380      0.586000
# 1           0.671   0.430    7   -12.920     0       0.0448      0.412000
# 2           0.712   0.569    6   -10.819     0       0.0348      0.346000
# 3           0.734   0.762    9    -7.013     0       0.0391      0.026100
# 4           0.650   0.498    8    -8.835     1       0.0596      0.572000
# ..            ...     ...  ...       ...   ...          ...           ...
# 195         0.806   0.836    1    -7.825     0       0.0762      0.000428
# 196         0.641   0.465   11   -15.887     0       0.0378      0.451000
# 197         0.800   0.878    2    -6.650     1       0.0715      0.028900
# 198         0.713   0.616    4   -15.033     0       0.0475      0.243000
# 199         0.802   0.890    9    -8.151     1       0.0447      0.045600
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### heart beats

# %%
heartbeats = sp.search(q="37i9dQZF1DWSRc3WJklgBs",limit=5,market="GB")
heartbeats

selected_playlist_heartbeats = get_playlist_tracks('spotify','37i9dQZF1DWSRc3WJklgBs')
selected_playlist_heartbeats

id_songs_heartbeats = []
for i in selected_playlist_heartbeats:
    id_songs_heartbeats.append(i['track']['id'])
id_songs_heartbeats

audio_list_heartbeats =[]
for i in id_songs_heartbeats:
    audio_list_heartbeats.append(sp.audio_features(i)[0])
audio_list_heartbeats

audio_list_heartbeats = pd.DataFrame(audio_list_heartbeats)
audio_list_heartbeats
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.636   0.869    9    -5.289     1       0.0412        0.0378
# 1           0.688   0.654    4    -8.521     1       0.0493        0.0203
# 2           0.593   0.643    5   -14.567     1       0.0623        0.5750
# 3           0.682   0.765    4    -5.593     1       0.0335        0.0194
# 4           0.354   0.641    6    -4.781     0       0.0342        0.0742
# ..            ...     ...  ...       ...   ...          ...           ...
# 203         0.551   0.719    4    -4.873     1       0.0477        0.0140
# 204         0.526   0.920    6    -4.493     1       0.0358        0.0524
# 205         0.710   0.827    6    -5.351     0       0.0450        0.0830
# 206         0.767   0.543   11   -12.701     1       0.0760        0.4600
# 207         0.637   0.866    9    -2.693     1       0.0356        0.3670
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### dubstep

# %%
dubstep = sp.search(q="37i9dQZF1DX5Q27plkaOQ3",limit=5,market="GB")
dubstep

selected_playlist_dubstep= get_playlist_tracks('spotify','37i9dQZF1DX5Q27plkaOQ3')
selected_playlist_dubstep

id_songs_dubstep = []
for i in selected_playlist_dubstep:
    id_songs_dubstep.append(i['track']['id'])
id_songs_dubstep

audio_list_dubstep =[]
for i in id_songs_dubstep:
    audio_list_dubstep.append(sp.audio_features(i)[0])
audio_list_dubstep

audio_list_dubstep = pd.DataFrame(audio_list_dubstep)
audio_list_dubstep
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.589   0.996    2    -1.210     1       0.3190      0.001480
# 1           0.702   0.926    2    -0.660     1       0.1480      0.000690
# 2           0.489   0.952    6    -1.909     1       0.0795      0.007490
# 3           0.612   0.974    2    -2.255     1       0.0930      0.000781
# 4           0.537   0.995   11     0.109     1       0.4490      0.293000
# ..            ...     ...  ...       ...   ...          ...           ...
# 120         0.476   0.878    1    -2.739     1       0.0786      0.001440
# 121         0.575   0.963   10    -5.496     0       0.1110      0.006110
# 122         0.414   0.869   11    -2.284     1       0.0565      0.186000
# 123         0.646   0.983   11    -3.735     0       0.0506      0.059600
# 124         0.477   0.935    0    -4.176     1       0.1460      0.004790
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### trance

# %%
trance = sp.search(q="37i9dQZF1DX91oIci4su1D",limit=5,market="GB")
trance

selected_playlist_trance = get_playlist_tracks('spotify','37i9dQZF1DX91oIci4su1D')
selected_playlist_trance

id_songs_trance = []
for i in selected_playlist_trance:
    id_songs_trance.append(i['track']['id'])
id_songs_trance

audio_list_trance =[]
for i in id_songs_trance:
    audio_list_trance.append(sp.audio_features(i)[0])
audio_list_trance

audio_list_trance = pd.DataFrame(audio_list_trance)
audio_list_trance
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.584   0.935    6    -9.576     1       0.0615      0.011700
# 1           0.520   0.940   10    -6.004     0       0.0391      0.000663
# 2           0.623   0.780   10    -6.789     0       0.0532      0.001500
# 3           0.645   0.891    9    -4.394     1       0.0382      0.058800
# 4           0.444   0.974    2    -5.026     0       0.0577      0.001550
# ..            ...     ...  ...       ...   ...          ...           ...
# 172         0.422   0.998    8    -4.016     1       0.0911      0.001260
# 173         0.545   0.922   11    -5.101     0       0.1550      0.006680
# 174         0.539   0.917    6    -7.153     0       0.0366      0.001300
# 175         0.742   0.820    4    -5.409     0       0.1100      0.025100
# 176         0.441   0.996    2    -4.289     1       0.1510      0.001430
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### happy beats

# %%
happybeats = sp.search(q="37i9dQZF1DWSf2RDTDayIx",limit=5,market="GB")
happybeats

selected_playlist_happybeats = get_playlist_tracks('spotify','37i9dQZF1DWSf2RDTDayIx')
selected_playlist_happybeats

id_songs_happybeats = []
for i in selected_playlist_happybeats:
    id_songs_happybeats.append(i['track']['id'])
id_songs_happybeats

audio_list_happybeats =[]
for i in id_songs_happybeats:
    audio_list_happybeats.append(sp.audio_features(i)[0])
audio_list_happybeats

audio_list_happybeats = pd.DataFrame(audio_list_happybeats)
audio_list_happybeats
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.796   0.798    1    -6.312     1       0.0317       0.03400
# 1           0.687   0.818    0    -4.221     1       0.0778       0.01120
# 2           0.739   0.586   10    -5.079     0       0.0472       0.02450
# 3           0.578   0.912    1    -3.929     1       0.1140       0.01660
# 4           0.736   0.906    0    -7.589     1       0.0480       0.16400
# ..            ...     ...  ...       ...   ...          ...           ...
# 145         0.689   0.897   11    -6.703     0       0.0436       0.00074
# 146         0.498   0.745   11    -5.801     0       0.0316       0.05740
# 147         0.689   0.822    0    -6.678     0       0.0430       0.00677
# 148         0.602   0.690    3    -5.801     1       0.0408       0.15900
# 149         0.601   0.832    0    -5.471     1       0.1390       0.02840
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### mint acoustic

# %%
mintacoustic = sp.search(q="37i9dQZF1DX5GiUwx1edLZ",limit=5,market="GB")
mintacoustic

selected_playlist_mintacoustic = get_playlist_tracks('spotify','37i9dQZF1DX5GiUwx1edLZ')
selected_playlist_mintacoustic

id_songs_mintacoustic = []
for i in selected_playlist_mintacoustic:
    id_songs_mintacoustic.append(i['track']['id'])
id_songs_mintacoustic

audio_list_mintacoustic =[]
for i in id_songs_mintacoustic:
    audio_list_mintacoustic.append(sp.audio_features(i)[0])
audio_list_mintacoustic

audio_list_mintacoustic = pd.DataFrame(audio_list_mintacoustic)
audio_list_mintacoustic
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.707   0.430    7    -6.794     0       0.0306         0.786
# 1          0.681   0.174    1    -8.745     1       0.0315         0.837
# 2          0.465   0.481    8    -2.533     1       0.0315         0.312
# 3          0.620   0.379    3    -8.675     1       0.0412         0.797
# 4          0.452   0.633    7    -4.231     1       0.0343         0.331
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.277   0.540    3    -3.501     1       0.0416         0.902
# 96         0.512   0.372    5    -5.749     0       0.0310         0.803
# 97         0.568   0.339    6   -11.213     1       0.0296         0.682
# 98         0.735   0.434    2    -5.783     0       0.0338         0.731
# 99         0.333   0.409    5    -7.841     1       0.0396         0.929
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### love deluxe

# %%
lovedeluxe = sp.search(q="37i9dQZF1DWVEvzGeX3eRs",limit=5,market="GB")
lovedeluxe

selected_playlist_lovedeluxe = get_playlist_tracks('spotify','37i9dQZF1DWVEvzGeX3eRs')
selected_playlist_lovedeluxe

id_songs_lovedeluxe = []
for i in selected_playlist_lovedeluxe:
    id_songs_lovedeluxe.append(i['track']['id'])
id_songs_lovedeluxe

audio_list_lovedeluxe =[]
for i in id_songs_lovedeluxe:
    audio_list_lovedeluxe.append(sp.audio_features(i)[0])
audio_list_lovedeluxe

audio_list_lovedeluxe = pd.DataFrame(audio_list_lovedeluxe)
audio_list_lovedeluxe
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.557   0.160    5   -16.302     0       0.0315       0.92200
# 1          0.568   0.495    1    -8.964     1       0.0299       0.35300
# 2          0.685   0.380    8   -11.219     1       0.1120       0.37300
# 3          0.762   0.459    0   -10.307     1       0.0379       0.11100
# 4          0.626   0.441    9   -10.637     0       0.0308       0.76100
# 5          0.699   0.388    6   -10.722     1       0.0531       0.58800
# 6          0.699   0.492    9    -9.449     0       0.0318       0.48400
# 7          0.654   0.417    5    -7.699     1       0.0250       0.06240
# 8          0.726   0.501    1   -13.884     0       0.1540       0.15500
# 9          0.539   0.363   10   -13.888     0       0.1660       0.70100
# 10         0.815   0.364    8   -11.834     0       0.0890       0.14000
# 11         0.662   0.344    9   -13.930     0       0.0487       0.36900
# ...

# %% [markdown]
# #### wine and dine

# %%
wnd= sp.search(q="37i9dQZF1DWTJNOeepZTGy",limit=5,market="GB")
wnd

selected_playlist_wnd = get_playlist_tracks('spotify','37i9dQZF1DWTJNOeepZTGy')
selected_playlist_wnd

id_songs_wnd = []
for i in selected_playlist_wnd:
    id_songs_wnd.append(i['track']['id'])
id_songs_wnd

audio_list_wnd =[]
for i in id_songs_wnd:
    audio_list_wnd.append(sp.audio_features(i)[0])
audio_list_wnd

audio_list_wnd = pd.DataFrame(audio_list_wnd)
audio_list_wnd
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.569  0.5960    8    -6.486     1       0.1720       0.45200
# 1          0.656  0.4790    7    -7.055     0       0.0348       0.06650
# 2          0.659  0.2950   11    -8.528     0       0.0322       0.42600
# 3          0.588  0.5220    9    -6.254     0       0.0383       0.23300
# 4          0.815  0.3640    8   -11.834     0       0.0890       0.14000
# 5          0.747  0.3980    5   -12.932     0       0.0743       0.21100
# 6          0.221  0.2640   10   -17.533     1       0.0332       0.54100
# 7          0.505  0.6690   10    -7.255     0       0.0231       0.42800
# 8          0.689  0.5620    7    -7.048     0       0.0637       0.06560
# 9          0.469  0.5940    7    -8.209     1       0.0403       0.06630
# 10         0.468  0.1490    5   -13.976     0       0.0363       0.46400
# 11         0.496  0.4880    5   -14.195     1       0.0305       0.29500
# ...

# %% [markdown]
# #### christian gospel

# %%
cgospel = sp.search(q="37i9dQZF1DXbrknLz4Do7C",limit=5,market="GB")
cgospel 

selected_playlist_cgospel  = get_playlist_tracks('spotify','37i9dQZF1DXbrknLz4Do7C')
selected_playlist_cgospel 

id_songs_cgospel  = []
for i in selected_playlist_cgospel :
    id_songs_cgospel .append(i['track']['id'])
id_songs_cgospel 

audio_list_cgospel  =[]
for i in id_songs_cgospel :
    audio_list_cgospel .append(sp.audio_features(i)[0])
audio_list_cgospel 

audio_list_cgospel  = pd.DataFrame(audio_list_cgospel )
audio_list_cgospel
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.394   0.608    0    -6.158     1       0.0417        0.2780
# 1          0.464   0.126   11   -16.383     1       0.0647        0.8160
# 2          0.453   0.785    8    -5.616     1       0.0481        0.0905
# 3          0.490   0.613    8    -6.457     1       0.0384        0.0569
# 4          0.492   0.429    4    -8.126     1       0.0392        0.0368
# ..           ...     ...  ...       ...   ...          ...           ...
# 65         0.690   0.648    2    -7.112     1       0.1820        0.0195
# 66         0.499   0.777    0    -6.722     1       0.1250        0.0840
# 67         0.274   0.400    7    -7.293     1       0.0300        0.4180
# 68         0.554   0.771   10    -5.539     1       0.0732        0.0308
# 69         0.265   0.539    5    -6.968     1       0.0353        0.0655
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### hillsong

# %%
hillsong = sp.search(q="17tw7L3cHFF9FcsFuiTcJA",limit=5,market="GB")
hillsong

selected_playlist_hillsong = get_playlist_tracks('David Dorner','17tw7L3cHFF9FcsFuiTcJA')
selected_playlist_hillsong

id_songs_hillsong = []
for i in selected_playlist_hillsong:
    id_songs_hillsong.append(i['track']['id'])
id_songs_hillsong

audio_list_hillsong =[]
for i in id_songs_hillsong:
    audio_list_hillsong.append(sp.audio_features(i)[0])
audio_list_hillsong

audio_list_hillsong = pd.DataFrame(audio_list_hillsong)
audio_list_hillsong
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.379   0.489    7    -7.051     1       0.0281       0.29300
# 1           0.417   0.499    2    -6.364     1       0.0296       0.21200
# 2           0.427   0.612    0    -6.812     1       0.0309       0.01050
# 3           0.391   0.568    0    -6.698     1       0.0310       0.04770
# 4           0.453   0.802    9    -6.636     1       0.0446       0.08930
# ..            ...     ...  ...       ...   ...          ...           ...
# 146         0.558   0.858    0    -6.500     1       0.0431       0.00571
# 147         0.454   0.525    9    -7.567     1       0.0284       0.02670
# 148         0.352   0.433    5    -9.485     1       0.0285       0.06010
# 149         0.228   0.527    5    -7.720     1       0.0359       0.00189
# 150         0.333   0.520    0    -9.746     1       0.0315       0.18200
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### old love songs

# %%
oldlove = sp.search(q="3CTdtnqOxTf6ZzKBObjg3n",limit=5,market="GB")
oldlove

selected_playlist_oldlove = get_playlist_tracks('Adrian Clements','3CTdtnqOxTf6ZzKBObjg3n')
selected_playlist_oldlove

id_songs_oldlove = []
for i in selected_playlist_oldlove:
    id_songs_oldlove.append(i['track']['id'])
id_songs_oldlove

audio_list_oldlove =[]
for i in id_songs_oldlove:
    audio_list_oldlove.append(sp.audio_features(i)[0])
audio_list_oldlove

audio_list_oldlove = pd.DataFrame(audio_list_oldlove)
audio_list_oldlove
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.744   0.453    5   -11.977     1       0.0348        0.6270
# 1           0.820   0.452    1    -9.796     1       0.0348        0.5430
# 2           0.497   0.719    6    -9.397     1       0.0266        0.0613
# 3           0.382   0.589    9    -7.315     0       0.0267        0.0465
# 4           0.548   0.294   10   -17.112     1       0.0333        0.3320
# ..            ...     ...  ...       ...   ...          ...           ...
# 210         0.431   0.678    4    -7.945     1       0.0365        0.7000
# 211         0.527   0.308    0   -11.809     1       0.0284        0.5510
# 212         0.596   0.631    2    -8.944     1       0.1310        0.4090
# 213         0.619   0.686    1    -9.014     0       0.0615        0.6440
# 214         0.490   0.715    7    -5.549     1       0.0476        0.3860
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### best of the decade for you

# %%
decadeforyou = sp.search(q="37i9dQZF1DXaMu9xyX1HzK",limit=5,market="GB")
decadeforyou

selected_playlist_decadeforyou = get_playlist_tracks('spotify','37i9dQZF1DXaMu9xyX1HzK')
selected_playlist_decadeforyou

id_songs_decadeforyou = []
for i in selected_playlist_decadeforyou:
    id_songs_decadeforyou.append(i['track']['id'])
id_songs_decadeforyou

audio_list_decadeforyou =[]
for i in id_songs_decadeforyou:
    audio_list_decadeforyou.append(sp.audio_features(i)[0])
audio_list_decadeforyou

audio_list_decadeforyou = pd.DataFrame(audio_list_decadeforyou)
audio_list_decadeforyou
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.679   0.587    7    -7.015     1       0.2760       0.14100
# 1          0.612   0.807   10    -2.810     1       0.0336       0.04950
# 2          0.690   0.521   10    -8.492     0       0.3390       0.32400
# 3          0.501   0.405    1    -5.679     1       0.0319       0.75100
# 4          0.599   0.448    8    -6.312     1       0.0232       0.16300
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.603   0.670    2    -3.882     0       0.0249       0.00408
# 96         0.740   0.613    8    -4.880     1       0.1450       0.25800
# 97         0.654   0.760    0    -3.669     0       0.0450       0.07970
# 98         0.764   0.718    9    -5.180     0       0.0703       0.00261
# 99         0.655   0.797    2    -4.787     1       0.1530       0.19800
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### new music friday DE

# %%
newfriday = sp.search(q="37i9dQZF1DWUW2bvSkjcJ6",limit=5,market="DE")
newfriday

selected_playlist_newfriday = get_playlist_tracks('spotify','37i9dQZF1DWUW2bvSkjcJ6')
selected_playlist_newfriday

id_songs_newfriday = []
for i in selected_playlist_newfriday:
    id_songs_newfriday.append(i['track']['id'])
id_songs_newfriday

audio_list_newfriday =[]
for i in id_songs_newfriday:
    audio_list_newfriday.append(sp.audio_features(i)[0])
audio_list_newfriday

audio_list_newfriday = pd.DataFrame(audio_list_newfriday)
audio_list_newfriday
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.701   0.613   10    -9.262     0       0.1720        0.2320
# 1          0.820   0.842    9    -4.085     0       0.1190        0.1030
# 2          0.577   0.969    9    -3.367     1       0.0673        0.0488
# 3          0.720   0.794    6    -2.644     1       0.0862        0.3780
# 4          0.841   0.883    8    -6.780     1       0.2270        0.2210
# ..           ...     ...  ...       ...   ...          ...           ...
# 85         0.684   0.614    2    -7.944     0       0.0334        0.4790
# 86         0.844   0.911   11    -5.601     0       0.1280        0.0893
# 87         0.678   0.760    5    -6.912     1       0.0332        0.2630
# 88         0.823   0.486    5    -9.210     0       0.1060        0.5340
# 89         0.823   0.569    5    -6.229     0       0.0591        0.2150
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### k-pop

# %%
kpop = sp.search(q="2EoheVFjqIxgJMb8VnDRtZ",limit=5,market="GB")
kpop

selected_playlist_kpop = get_playlist_tracks('nbe2awe','2EoheVFjqIxgJMb8VnDRtZ')
selected_playlist_kpop

id_songs_kpop = []
for i in selected_playlist_kpop:
    id_songs_kpop.append(i['track']['id'])
id_songs_kpop

audio_list_kpop =[]
for i in id_songs_kpop:
    audio_list_kpop.append(sp.audio_features(i)[0])
audio_list_kpop

audio_list_kpop = pd.DataFrame(audio_list_kpop)
audio_list_kpop
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.774   0.660    2    -8.200     1       0.0328       0.66200
# 1           0.815   0.834    4    -2.828     0       0.0475       0.03270
# 2           0.795   0.875    4    -4.079     0       0.0525       0.11100
# 3           0.804   0.771    9    -4.067     0       0.0433       0.35700
# 4           0.765   0.650    6    -6.043     1       0.0372       0.06690
# ..            ...     ...  ...       ...   ...          ...           ...
# 170         0.636   0.810    1    -2.035     1       0.1010       0.02050
# 171         0.688   0.831    0    -2.857     1       0.0962       0.06970
# 172         0.819   0.550    0    -6.570     1       0.0434       0.03670
# 173         0.785   0.907   10    -2.657     1       0.0938       0.00122
# 174         0.604   0.886    4    -3.523     0       0.0610       0.09250
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### classical essentials

# %%
classical_essentials = sp.search(q="37i9dQZF1DWWEJlAGA9gs0",limit=5,market="GB")
classical_essentials

selected_playlist_classical_essentials = get_playlist_tracks('spotify','37i9dQZF1DWWEJlAGA9gs0')
selected_playlist_classical_essentials

id_songs_classical_essentials = []
for i in selected_playlist_classical_essentials:
    id_songs_classical_essentials.append(i['track']['id'])
id_songs_classical_essentials

audio_list_classical_essentials =[]
for i in id_songs_classical_essentials:
    audio_list_classical_essentials.append(sp.audio_features(i)[0])
audio_list_classical_essentials

audio_list_classical_essentials = pd.DataFrame(audio_list_classical_essentials)
audio_list_classical_essentials
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.2570  0.1090    7   -21.356     1       0.0597         0.900
# 1          0.2210  0.1260    0   -25.427     1       0.0447         0.989
# 2          0.2890  0.0306    9   -30.790     0       0.0446         0.987
# 3          0.0769  0.0846    2   -25.997     1       0.0450         0.922
# 4          0.1280  0.1320    2   -17.670     1       0.0353         0.744
# ..            ...     ...  ...       ...   ...          ...           ...
# 147        0.2400  0.0834    6   -29.545     0       0.0499         0.978
# 148        0.4050  0.3180    9   -17.140     1       0.0565         0.938
# 149        0.2910  0.0981    8   -23.156     1       0.0398         0.950
# 150        0.0992  0.2260    9   -14.840     0       0.0339         0.937
# 151        0.3390  0.0937    2   -20.267     1       0.0394         0.931
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### punk

# %%
punkcl = sp.search(q="5XEDGTA0v2FGh8O2Qid8BX",limit=5,market="DE")
punkcl

selected_playlist_punkcl = get_playlist_tracks('Filtr Legacy Sweden','5XEDGTA0v2FGh8O2Qid8BX')
selected_playlist_punkcl

id_songs_punkcl = []
for i in selected_playlist_punkcl:
    id_songs_punkcl.append(i['track']['id'])
id_songs_punkcl

audio_list_punkcl =[]
for i in id_songs_punkcl:
    audio_list_punkcl.append(sp.audio_features(i)[0])
audio_list_punkcl

audio_list_punkcl = pd.DataFrame(audio_list_punkcl)
audio_list_punkcl
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.359   0.949    0    -7.649     1       0.1010      0.055600
# 1           0.190   0.964    1    -7.711     0       0.1010      0.005490
# 2           0.345   0.998    8     1.275     1       0.2290      0.075600
# 3           0.168   0.974    2    -4.862     1       0.0655      0.000598
# 4           0.325   0.688    4   -12.473     1       0.1170      0.179000
# ..            ...     ...  ...       ...   ...          ...           ...
# 257         0.574   0.536    0   -12.849     1       0.0893      0.516000
# 258         0.250   0.640    1    -8.745     1       0.1100      0.072000
# 259         0.832   0.792    7    -6.052     1       0.0657      0.197000
# 260         0.518   0.913    9    -4.574     1       0.0550      0.032500
# 261         0.387   0.906    4    -4.536     1       0.1020      0.001350
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### folk pop

# %%
folkpop = sp.search(q="37i9dQZF1DWXJyjYpHunCf",limit=5,market="GB")
folkpop

selected_playlist_folkpop = get_playlist_tracks('spotify','37i9dQZF1DWXJyjYpHunCf')
selected_playlist_folkpop

id_songs_folkpop = []
for i in selected_playlist_folkpop:
    id_songs_folkpop.append(i['track']['id'])
id_songs_folkpop

audio_list_folkpop =[]
for i in id_songs_folkpop:
    audio_list_folkpop.append(sp.audio_features(i)[0])
audio_list_folkpop

audio_list_folkpop = pd.DataFrame(audio_list_folkpop)
audio_list_folkpop
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.693   0.595    8    -7.578     1       0.0311        0.0969
# 1          0.792   0.518    1   -10.519     1       0.0847        0.3260
# 2          0.524   0.712    0    -7.474     1       0.0518        0.0201
# 3          0.516   0.322    9   -11.762     1       0.0292        0.4730
# 4          0.411   0.513    1    -9.466     0       0.0342        0.1920
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.666   0.533    1    -8.816     1       0.0367        0.2920
# 96         0.573   0.336    5   -13.754     0       0.0514        0.7230
# 97         0.527   0.438    7    -9.962     1       0.0294        0.5040
# 98         0.599   0.522    2    -5.203     1       0.0371        0.0904
# 99         0.567   0.242   10   -11.616     1       0.0487        0.8790
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### blues guitar

# %%
bluesguitar = sp.search(q="2ZPbHrBWpcnEsWWO00szW8",limit=5,market="DE")
bluesguitar

selected_playlist_bluesguitar = get_playlist_tracks('Alec Wilson','2ZPbHrBWpcnEsWWO00szW8')
selected_playlist_bluesguitar

id_songs_bluesguitar = []
for i in selected_playlist_bluesguitar:
    id_songs_bluesguitar.append(i['track']['id'])
id_songs_bluesguitar

audio_list_bluesguitar =[]
for i in id_songs_bluesguitar:
    audio_list_bluesguitar.append(sp.audio_features(i)[0])
audio_list_bluesguitar

audio_list_bluesguitar = pd.DataFrame(audio_list_bluesguitar)
audio_list_bluesguitar
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.646   0.395    1   -12.828     0       0.2540        0.2690
# 1          0.659   0.521    0   -11.242     0       0.0306        0.4790
# 2          0.746   0.560    5   -14.789     1       0.0565        0.4940
# 3          0.601   0.190    5   -18.675     1       0.0610        0.5070
# 4          0.673   0.239    2   -10.525     0       0.2410        0.8820
# ..           ...     ...  ...       ...   ...          ...           ...
# 66         0.547   0.598    2   -15.029     1       0.0269        0.5970
# 67         0.593   0.466    0   -13.302     1       0.0269        0.0416
# 68         0.372   0.500    9   -13.351     1       0.1280        0.2210
# 69         0.483   0.804    0    -8.889     1       0.0871        0.0360
# 70         0.309   0.343    9   -12.063     0       0.0263        0.4230
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### acoustic covers

# %%
acousticcovers = sp.search(q="37i9dQZF1DWXmlLSKkfdAk",limit=5,market="DE")
acousticcovers

selected_playlist_acousticcovers = get_playlist_tracks('spotify','37i9dQZF1DWXmlLSKkfdAk')
selected_playlist_acousticcovers

id_songs_acousticcovers= []
for i in selected_playlist_acousticcovers:
    id_songs_acousticcovers.append(i['track']['id'])
id_songs_acousticcovers

audio_list_acousticcovers =[]
for i in id_songs_acousticcovers:
    audio_list_acousticcovers.append(sp.audio_features(i)[0])
audio_list_acousticcovers

audio_list_acousticcovers = pd.DataFrame(audio_list_acousticcovers)
audio_list_acousticcovers
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.456  0.2500    9   -10.285     1       0.0298        0.9850
# 1           0.699  0.0757    2   -13.588     1       0.0353        0.9850
# 2           0.627  0.2470    1   -13.303     1       0.0321        0.8110
# 3           0.447  0.1600    0   -13.145     1       0.0370        0.8800
# 4           0.581  0.2250    1   -11.588     1       0.0478        0.7000
# ..            ...     ...  ...       ...   ...          ...           ...
# 208         0.611  0.2960    0    -6.512     1       0.0285        0.7440
# 209         0.755  0.6430    9    -9.097     0       0.0268        0.0264
# 210         0.558  0.1720    8   -13.379     1       0.0513        0.8740
# 211         0.404  0.1670    9   -12.463     0       0.0604        0.8910
# 212         0.467  0.3070    0    -9.712     1       0.0284        0.5560
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### lofi

# %%
lofi = sp.search(q="37i9dQZF1DWWQRwui0ExPn",limit=5,market="GB")
lofi

selected_playlist_lofi = get_playlist_tracks('spotify','37i9dQZF1DWWQRwui0ExPn')
selected_playlist_lofi

id_songs_lofi = []
for i in selected_playlist_lofi:
    id_songs_lofi.append(i['track']['id'])
id_songs_lofi

audio_list_lofi =[]
for i in id_songs_lofi:
    audio_list_lofi.append(sp.audio_features(i)[0])
audio_list_lofi

audio_list_lofi = pd.DataFrame(audio_list_lofi)
audio_list_lofi
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.484   0.473    8   -12.727     1       0.0949        0.7100
# 1           0.741   0.394    1   -15.079     1       0.0863        0.0925
# 2           0.605   0.328    1    -9.196     1       0.1050        0.8030
# 3           0.783   0.293    6   -10.204     0       0.1220        0.9050
# 4           0.645   0.426    7   -12.453     0       0.0474        0.0191
# ..            ...     ...  ...       ...   ...          ...           ...
# 745         0.668   0.428    2   -12.212     1       0.0968        0.7130
# 746         0.696   0.335   10   -11.916     0       0.2170        0.4990
# 747         0.667   0.493    0    -7.995     0       0.0435        0.4100
# 748         0.671   0.441    7    -7.765     1       0.1270        0.8360
# 749         0.469   0.195    2   -15.837     0       0.1290        0.8260
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### summer dance hits

# %%
summerdance = sp.search(q="37i9dQZF1DWZ7eJRBxKzdO",limit=5,market="DE")
summerdance

selected_playlist_summerdance = get_playlist_tracks('spotify','37i9dQZF1DWZ7eJRBxKzdO')
selected_playlist_summerdance

id_songs_summerdance = []
for i in selected_playlist_summerdance:
    id_songs_summerdance.append(i['track']['id'])
id_songs_summerdance

audio_list_summerdance =[]
for i in id_songs_summerdance:
    audio_list_summerdance.append(sp.audio_features(i)[0])
audio_list_summerdance

audio_list_summerdance = pd.DataFrame(audio_list_summerdance)
audio_list_summerdance
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.561   0.965    7    -3.673     0       0.0343       0.00383
# 1           0.636   0.869    9    -5.289     1       0.0412       0.03780
# 2           0.775   0.817    1    -4.921     1       0.0656       0.12700
# 3           0.671   0.876    7    -5.681     0       0.0352       0.12000
# 4           0.671   0.636    6    -8.117     0       0.1030       0.51500
# ..            ...     ...  ...       ...   ...          ...           ...
# 115         0.671   0.855    7    -4.254     0       0.0375       0.00437
# 116         0.675   0.899    9    -4.787     0       0.0391       0.00250
# 117         0.728   0.657    0    -5.329     0       0.0420       0.06960
# 118         0.713   0.772    2    -5.032     1       0.0313       0.15700
# 119         0.796   0.637    5    -7.389     1       0.0342       0.21700
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### pop scream

# %%
popscream = sp.search(q="37i9dQZF1DX2KwEtNSejGe",limit=5,market="DE")
popscream

selected_playlist_popscream = get_playlist_tracks('spotify','37i9dQZF1DX2KwEtNSejGe')
selected_playlist_popscream

id_songs_popscream = []
for i in selected_playlist_popscream:
    id_songs_popscream.append(i['track']['id'])
id_songs_popscream

audio_list_popscream =[]
for i in id_songs_popscream:
    audio_list_popscream.append(sp.audio_features(i)[0])
audio_list_popscream

audio_list_popscream = pd.DataFrame(audio_list_popscream)
audio_list_popscream
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.783   0.580    7    -6.548     1       0.0408       0.01140
# 1          0.726   0.787    4    -2.494     1       0.0737       0.00900
# 2          0.567   0.686    7    -6.139     1       0.1750       0.03170
# 3          0.628   0.593    8    -5.036     1       0.0323       0.09300
# 4          0.608   0.860    5    -5.324     0       0.0554       0.09910
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.536   0.768   10    -5.948     0       0.0347       0.00433
# 96         0.757   0.678    8    -5.529     0       0.2330       0.04720
# 97         0.781   0.728    1    -4.981     1       0.0621       0.05090
# 98         0.674   0.881    9    -2.853     1       0.1470       0.29600
# 99         0.587   0.828   11    -5.108     1       0.1610       0.00327
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### disco fever

# %%
discofever = sp.search(q="37i9dQZF1DX2GKumqRIZ7g",limit=5,market="GB")
discofever

selected_playlist_discofever = get_playlist_tracks('spotify','37i9dQZF1DX2GKumqRIZ7g')
selected_playlist_discofever

id_songs_discofever = []
for i in selected_playlist_discofever:
    id_songs_discofever.append(i['track']['id'])
id_songs_discofever

audio_list_discofever =[]
for i in id_songs_discofever:
    audio_list_discofever.append(sp.audio_features(i)[0])
audio_list_discofever

audio_list_discofever = pd.DataFrame(audio_list_discofever)
audio_list_discofever
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.629   0.851    5   -11.182     0       0.0294       0.03090
# 1          0.796   0.892    0    -8.310     1       0.0333       0.00475
# 2          0.733   0.795    1    -7.224     0       0.0249       0.02660
# 3          0.781   0.556    5   -13.067     0       0.0611       0.06610
# 4          0.910   0.641    7   -11.316     1       0.0589       0.02580
# 5          0.720   0.828    5    -9.211     1       0.0462       0.18500
# 6          0.452   0.755    2    -8.344     1       0.0747       0.11300
# 7          0.766   0.857    2    -8.647     0       0.0300       0.04140
# 8          0.726   0.888    5    -7.191     0       0.0726       0.33500
# 9          0.704   0.868    2    -5.808     1       0.0315       0.08340
# 10         0.673   0.752    9    -7.978     0       0.0491       0.00309
# 11         0.857   0.700    2   -14.506     0       0.0358       0.00387
# ...

# %% [markdown]
# #### september radio

# %%
sepradio = sp.search(q="37i9dQZF1E8KixPw8XwHmu",limit=5,market="DE")
sepradio 

selected_playlist_sepradio  = get_playlist_tracks('spotify','37i9dQZF1E8KixPw8XwHmu')
selected_playlist_sepradio 

id_songs_sepradio  = []
for i in selected_playlist_sepradio :
    id_songs_sepradio .append(i['track']['id'])
id_songs_sepradio 

audio_list_sepradio  =[]
for i in id_songs_sepradio :
    audio_list_sepradio .append(sp.audio_features(i)[0])
audio_list_sepradio 

audio_list_sepradio  = pd.DataFrame(audio_list_sepradio )
audio_list_sepradio
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.802   0.756    2   -10.791     0       0.0349       0.08430
# 1          0.708   0.567   10   -15.539     0       0.0355       0.07000
# 2          0.784   0.893    7    -5.153     0       0.0923       0.30000
# 3          0.675   0.597    5   -11.329     1       0.0337       0.05340
# 4          0.701   0.803    5    -6.786     0       0.0545       0.05440
# 5          0.869   0.648   11    -8.698     0       0.0633       0.12100
# 6          0.784   0.713    0    -6.865     1       0.0339       0.44700
# 7          0.773   0.857    9    -2.997     1       0.0301       0.01390
# 8          0.469   0.538    8   -13.559     1       0.0571       0.30500
# 9          0.812   0.645    9   -12.265     0       0.0860       0.41100
# 10         0.729   0.954    9    -3.633     1       0.0358       0.10600
# 11         0.633   0.634    8   -12.115     1       0.0725       0.03800
# ...

# %% [markdown]
# #### throwback

# %%
throwback = sp.search(q="37i9dQZF1DX7F6T2n2fegs",limit=5,market="DE")
throwback

selected_playlist_throwback = get_playlist_tracks('spotify','37i9dQZF1DX7F6T2n2fegs')
selected_playlist_throwback

id_songs_throwback = []
for i in selected_playlist_throwback:
    id_songs_throwback.append(i['track']['id'])
id_songs_throwback

audio_list_throwback =[]
for i in id_songs_throwback:
    audio_list_throwback.append(sp.audio_features(i)[0])
audio_list_throwback

audio_list_throwback = pd.DataFrame(audio_list_throwback)
audio_list_throwback
# Out:
#      danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0           0.679   0.587    7    -7.015     1       0.2760       0.14100
# 1           0.908   0.669    7    -2.827     1       0.0738       0.00286
# 2           0.726   0.698    5    -4.165     1       0.0431       0.04900
# 3           0.825   0.652    1    -3.183     0       0.0802       0.58100
# 4           0.573   0.902    6    -7.638     0       0.0540       0.01800
# ..            ...     ...  ...       ...   ...          ...           ...
# 145         0.811   0.823    4    -5.921     0       0.0423       0.05530
# 146         0.783   0.580    7    -6.548     1       0.0408       0.01140
# 147         0.832   0.838    1    -5.414     0       0.0421       0.07910
# 148         0.727   0.937   11    -2.871     0       0.2860       0.00417
# 149         0.867   0.517   11   -13.222     0       0.0875       0.00456
#
#      instrumentalness  liveness  valence    tempo            type  \
# ...

# %% [markdown]
# #### antipop

# %%
antipop = sp.search(q="37i9dQZF1DWWqNV5cS50j6",limit=5,market="DE")
antipop 

selected_playlist_antipop  = get_playlist_tracks('spotify','37i9dQZF1DWWqNV5cS50j6')
selected_playlist_antipop 

id_songs_antipop  = []
for i in selected_playlist_antipop :
    id_songs_antipop .append(i['track']['id'])
id_songs_antipop 

audio_list_antipop  =[]
for i in id_songs_antipop :
    audio_list_antipop .append(sp.audio_features(i)[0])
audio_list_antipop 

audio_list_antipop  = pd.DataFrame(audio_list_antipop )
audio_list_antipop
# Out:
#     danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0          0.753   0.803    9    -5.080     1       0.0438       0.00200
# 1          0.804   0.722    0    -4.502     1       0.0526       0.07940
# 2          0.562   0.685    4    -7.080     0       0.2080       0.06570
# 3          0.750   0.773    1    -4.554     0       0.0411       0.00235
# 4          0.744   0.690    1    -5.669     0       0.0391       0.00797
# ..           ...     ...  ...       ...   ...          ...           ...
# 95         0.700   0.829    8    -6.846     1       0.0669       0.00218
# 96         0.555   0.614    0    -8.679     1       0.0997       0.81800
# 97         0.396   0.594    9    -5.267     0       0.1140       0.38400
# 98         0.570   0.450    2    -7.241     1       0.0271       0.41500
# 99         0.718   0.663    9    -7.499     1       0.0956       0.01140
#
#     instrumentalness  liveness  valence    tempo            type  \
# ...

# %%
combined_df = pd.concat([audio_list_todays_top,audio_list_global_top,audio_list_rapcaviar,audio_list_vivalatino,audio_list_stsitc,audio_list_allout00,audio_list_rockclassics,audio_list_allout80s,audio_list_beastmode,audio_list_allout90s,audio_list_chillhits,audio_list_peacefulpiano,audio_list_hotcountry,audio_list_moodbooster,audio_list_stsits,audio_list_mint,audio_list_esquentasertanejo,audio_list_happyhits,audio_list_crossgenre,audio_list_multigenre,audio_list_dancehall,audio_list_africanheat,audio_list_softpop,audio_list_workouttwerkout,audio_list_youandme,audio_list_rocksolid,audio_list_soakupthesun,audio_list_wildcountry,audio_list_country90s,audio_list_soullounge,audio_list_funk,audio_list_deephouse,audio_list_heartbeats,audio_list_dubstep,audio_list_trance,audio_list_happybeats,audio_list_mintacoustic,audio_list_lovedeluxe,audio_list_wnd,audio_list_cgospel,audio_list_hillsong,audio_list_oldlove,audio_list_decadeforyou,audio_list_newfriday,audio_list_kpop,audio_list_classical_essentials,audio_list_punkcl,audio_list_folkpop,audio_list_bluesguitar,audio_list_acousticcovers,audio_list_lofi,audio_list_summerdance,audio_list_popscream,audio_list_discofever,audio_list_sepradio,audio_list_throwback,audio_list_antipop ], ignore_index=True)

# %%
combined_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.552   0.702    9    -5.707     1       0.1570       0.11700
# 1            0.511   0.532    5    -5.745     1       0.0560       0.16900
# 2            0.855   0.678    1    -6.276     1       0.1890       0.05690
# 3            0.671   0.845   11    -4.930     0       0.0480       0.02070
# 4            0.652   0.800    9    -4.019     0       0.0614       0.14300
# ...            ...     ...  ...       ...   ...          ...           ...
# 6918         0.700   0.829    8    -6.846     1       0.0669       0.00218
# 6919         0.555   0.614    0    -8.679     1       0.0997       0.81800
# 6920         0.396   0.594    9    -5.267     0       0.1140       0.38400
# 6921         0.570   0.450    2    -7.241     1       0.0271       0.41500
# 6922         0.718   0.663    9    -7.499     1       0.0956       0.01140
#
# ...

# %%
# Check for duplicates
duplicate_rows = combined_df.duplicated()

# Count the number of duplicates
num_duplicates = duplicate_rows.sum()

print("Number of duplicates:", num_duplicates)
# Out:
# Number of duplicates: 1146

# %%
# Drop duplicates
combined_df = combined_df.drop_duplicates()

# Optional: Reset the index after dropping duplicates
combined_df = combined_df.reset_index(drop=True)

# %%
combined_df
# Out:
#       danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 0            0.552   0.702    9    -5.707     1       0.1570       0.11700
# 1            0.511   0.532    5    -5.745     1       0.0560       0.16900
# 2            0.855   0.678    1    -6.276     1       0.1890       0.05690
# 3            0.671   0.845   11    -4.930     0       0.0480       0.02070
# 4            0.652   0.800    9    -4.019     0       0.0614       0.14300
# ...            ...     ...  ...       ...   ...          ...           ...
# 5772         0.700   0.829    8    -6.846     1       0.0669       0.00218
# 5773         0.555   0.614    0    -8.679     1       0.0997       0.81800
# 5774         0.396   0.594    9    -5.267     0       0.1140       0.38400
# 5775         0.570   0.450    2    -7.241     1       0.0271       0.41500
# 5776         0.718   0.663    9    -7.499     1       0.0956       0.01140
#
# ...

# %%
combined_df.to_csv('combined.csv', index=False)
